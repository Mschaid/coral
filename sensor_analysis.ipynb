# %%
import polars as pl
import seaborn as sns
import pandas as pd

# %%
original_sensor = "/Users/mds8301/Desktop/temp/photosensor_test/3634-240307-094143/3634-240307-094143_output_1/cue_LHA_z_score_LHA.h5"
new_sensor =  "/Users/mds8301/Desktop/temp/photosensor_test/3634-240307-122935/3634-240307-122935_output_1/cue_LHA_z_score_LHA.h5"

# %%
orig_data = pd.read_hdf(original_sensor)
new_data = pd.read_hdf(new_sensor)

# %%
sns.lineplot(data = orig_data, x = 'timestamps', y='mean')
sns.lineplot(data=new_data,x = 'timestamps',y= 'mean')
# Out:
# <Axes: xlabel='timestamps', ylabel='mean'>
